# %% [markdown]
# # Ollama in Jupyter Notebook
# Run this within the virtual environment **(env_ollama)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_ollama/bin/python

# %%
import ollama
result = ollama.generate(
    model="llama3.2",
    prompt="Write me a story on once upon a time there was a little boy."
)
answer = result.response
print(answer)
# Out:
# Once upon a time, in a small village nestled between two great oak trees, there lived a little boy named Timmy. Timmy was a curious and adventurous child, with eyes that sparkled like the stars on a clear night and hair as bright as the sun's first rays.
#
# Timmy lived with his loving parents and younger sister, Emma, in a cozy little cottage at the edge of the village. The cottage was surrounded by a lush garden filled with vibrant flowers, buzzing bees, and chirping birds that sang sweet melodies to Timmy every morning.
#
# One sunny afternoon, while exploring the woods near their home, Timmy stumbled upon a hidden path he had never seen before. The path was winding and narrow, leading deep into the heart of the forest. Feeling an insatiable sense of wonder and excitement, Timmy decided to follow it.
#
# ...

# %% [markdown]
# $\checkmark$
