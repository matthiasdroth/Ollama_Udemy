# %% [markdown]
# # Google Colab Ollama
# Run this within the virtual environment **(env_ollama)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_ollama/bin/python

# %%
import ollama
output = ollama.generate(model='llama3.2' , prompt='Write me a story on once upon a time there was a boy',)
print(output['response'])
# Out:
# Once upon a time, in a small village nestled between two great mountains, there lived a boy named Eryndor Thorne. He was a curious and adventurous child, with eyes that sparkled like the stars on a clear night and hair as dark as the forest that surrounded his home.
#
# Eryndor lived with his wise and kind grandmother, who had taught him everything she knew about the world and its secrets. She was a skilled healer, able to communicate with animals and sense the rhythms of nature in ways that few others could. Eryndor adored her, and spent hours by her side, listening as she told stories of old and sharing her own tales of magic and wonder.
#
# One day, while out exploring the forest, Eryndor stumbled upon a hidden path he had never seen before. The trees seemed to lean in, forming an arc that led him deeper into the woods, and the air grew thick with an otherworldly scent. Intrigued, Eryndor followed the path, his heart pounding in his chest as he wondered where it might lead.
#
# ...

# %% [markdown]
# $\checkmark$
