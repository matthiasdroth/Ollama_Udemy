# %% [markdown]
# # Checking GPU Support for PyTorch
# Run this within *any* virtual environment!
#
# Command for installing pytorch 1.9 with CUDA support on a system with NVidia driver 460.91.03:<br>
# `$ conda install pytorch==1.9.0 torchvision==0.10.0 torchaudio==0.9.0 cudatoolkit=10.2 -c pytorch`<br><br>
# See also https://pytorch.org/get-started/previous-versions.

# %%
import torch
print(torch.__version__)
torch.cuda.get_device_name(torch.cuda.current_device())
# Out:
# 2.7.1+cu118
# 'NVIDIA GeForce RTX 3060'

# %% [markdown]
# GeForce RTX rules!
