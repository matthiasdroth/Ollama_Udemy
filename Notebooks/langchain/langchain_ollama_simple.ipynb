# %% [markdown]
# # LangChain Ollama simple
# Run this within the virtual environment **(env_langchain)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_langchain/bin/python

# %%
from langchain_ollama import ChatOllama
ollama_client = ChatOllama(model="llama3.2")
prompt = "What is the capital of France?"
output = ollama_client.invoke(prompt)
print(f"{output.content}\n\n{output}")
# Out:
# The capital of France is Paris.
#
# content='The capital of France is Paris.' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2026-01-17T23:46:52.435124963Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2440145531, 'load_duration': 1979475068, 'prompt_eval_count': 32, 'prompt_eval_duration': 376445340, 'eval_count': 8, 'eval_duration': 82445947, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'} id='lc_run--019bce5a-b609-7b31-a59a-4e973d11319c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 32, 'output_tokens': 8, 'total_tokens': 40}

# %% [markdown]
# $\checkmark$
