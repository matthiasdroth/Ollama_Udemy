# %% [markdown]
# # LangChain Ollama Chaining
# Run this within the virtual environment **(env_langchain)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_langchain/bin/python

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
ollama_client = ChatOllama(model="llama3.2")
prompt = ChatPromptTemplate.from_messages([
    ("system" "You are a helpful assistant"),
    ("user" "{input}")
])
chain = prompt | ollama_client
output = chain.invoke({"input": "What is the capital of India?"})
print(f"{output.content}\n\n{output}")
# Out:
# The capital of India is New Delhi.
#
# content='The capital of India is New Delhi.' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2026-01-17T23:50:12.84781668Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7969652574, 'load_duration': 7500045543, 'prompt_eval_count': 40, 'prompt_eval_duration': 376295890, 'eval_count': 9, 'eval_duration': 91045552, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'} id='lc_run--019bce5d-af4c-7ab1-9473-392ba1914a98-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 9, 'total_tokens': 49}

# %% [markdown]
# $\checkmark$
