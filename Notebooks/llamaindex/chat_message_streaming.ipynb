# %% [markdown]
# # Chat Message Streaming
# Run this within the virtual environment **(env_llamaindex)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_llamaindex/bin/python

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.ollama import Ollama

llm = Ollama(model="llama3.2", request_timeout=60.0)
messages = [
	    ChatMessage(
	        role="system", content="You are a helful assistant"
	    ),
	    ChatMessage(role="user", content="Who is the PM of India?")
	]
response = llm.stream_chat(messages)
for r in response:
	print(r.delta , end="")
# Out:
# As of my knowledge cutoff in 2023, the Prime Minister of India is Narendra Modi. However, please note that this information may have changed since my knowledge cutoff date. For the most up-to-date information, I recommend checking with a reliable news source or official government website.

# %% [markdown]
# $\checkmark$
