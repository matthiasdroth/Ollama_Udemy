# %% [markdown]
# # LlamaIndex RAG
# Run this within the virtual environment **(env_llamaindex)**!

# %%
# !which python
# Out:
# /home/matthias/Desktop/MachineLearning/Ollama_Udemy/env_llamaindex/bin/python

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.ollama import OllamaEmbedding
# initialize models
llms = Ollama(model="llama3.2:latest")
embedding_model = OllamaEmbedding(model_name="nomic-embed-text")
# load documents and create index
documents = SimpleDirectoryReader("/home/matthias/Desktop/MachineLearning/Ollama_Udemy").load_data()
response = llms.complete("What is the Product Owner's job?")
print(response)
# Out:
# 2026-01-18 10:28:50,302 - INFO - HTTP Request: POST http://localhost:11434/api/show "HTTP/1.1 200 OK"
# 2026-01-18 10:29:15,501 - INFO - HTTP Request: POST http://localhost:11434/api/chat "HTTP/1.1 200 OK"
# The Product Owner is a critical role in Agile project management, responsible for ensuring that the product or service being developed meets the needs and expectations of its stakeholders. The primary goal of the Product Owner is to prioritize and define the product backlog, which is a list of features or user stories that need to be implemented.
#
# Some key responsibilities of a Product Owner include:
#
# 1. **Prioritization**: Prioritize the product backlog based on business value, customer needs, and other relevant factors.
# 2. **Product Vision**: Define and communicate the overall vision and goals of the product.
# ...

# %% [markdown]
# $\checkmark$
